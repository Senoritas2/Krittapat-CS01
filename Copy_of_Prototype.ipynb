# %% [markdown]
# <a href="https://colab.research.google.com/github/Senoritas2/Krittapat-CS01/blob/main/Copy_of_Prototype.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.datasets import load_digits
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn import metrics
import pylab
import pandas
import matplotlib.pyplot as plt  
import numpy as np

digits_dataset = load_digits()

# %%
#import info
df = pandas.read_csv('Muang_Chiang_Mai.csv')
df2 = pandas.DataFrame(df,columns=['Latitude','Longitude'])
products_list_x_train = df2.to_numpy()
print(products_list_x_train)
# Out:
# [[18.795623 98.916717]
#  [18.820281 98.888116]
#  [18.839306 98.960487]
#  [18.809087 98.942215]
#  [18.840801 98.961723]
#  [18.803107 98.977127]
#  [18.800696 98.934543]
#  [18.810409 98.983534]
#  [18.792531 98.942002]
#  [18.802386 98.973377]
#  [18.838527 98.944599]
#  [18.799683 98.917816]
#  [18.795101 98.990163]
#  [18.825437 98.897318]
#  [18.79332  98.926976]
#  [18.788215 98.922039]
#  [18.837159 98.894493]
#  [18.827882 98.920068]
#  [18.827093 98.927927]
#  [18.789973 98.983672]
#  [18.821078 98.919534]
#  [18.796948 98.985173]
#  [18.792518 98.921931]
#  [18.835667 98.966487]
#  [18.789713 98.888663]
#  [18.803089 98.903483]
#  [18.829605 98.898089]
#  [18.824257 98.928595]
#  [18.821408 98.936243]
#  [18.821436 98.936467]
#  [18.819098 98.979671]
#  [18.836013 98.918914]
#  [18.798615 98.970606]
#  [18.821366 98.889908]
#  [18.816103 98.911347]
#  [18.790293 98.921264]
#  [18.840839 98.918576]
#  [18.8274   98.997136]
#  [18.797063 98.934972]
#  [18.797125 98.953398]
# ...

# %% [markdown]
# # New Section

# %%
#import target
df3 = pandas.read_csv('Muang_Chiang_Mai.csv')
df4 = pandas.DataFrame(df,columns=[' Subdistrict'])
products_list_y_train = df4.to_numpy()
print(products_list_y_train)
# Out:
# [[ 1]
#  [ 3]
#  [ 8]
#  [ 5]
#  [11]
#  [12]
#  [ 6]
#  [ 5]
#  [ 1]
#  [11]
#  [ 4]
#  [ 2]
#  [ 2]
#  [ 6]
#  [11]
#  [15]
#  [ 9]
#  [ 8]
#  [15]
#  [ 7]
#  [ 3]
#  [ 7]
#  [ 3]
#  [ 4]
#  [ 7]
#  [ 3]
#  [15]
#  [ 9]
#  [ 7]
#  [ 1]
#  [ 1]
#  [ 2]
#  [13]
#  [ 5]
#  [ 4]
#  [ 1]
#  [ 2]
#  [10]
#  [11]
#  [13]
#  [ 2]
#  [ 7]
#  [11]
#  [ 5]
#  [15]
#  [ 4]
#  [11]
#  [ 1]
#  [ 1]
#  [11]
#  [ 2]
#  [ 6]
#  [ 6]
#  [ 7]
#  [ 6]
#  [ 8]
#  [ 4]
#  [ 4]
#  [ 2]
#  [ 2]
#  [ 7]
#  [ 1]
#  [15]
#  [14]
#  [15]
#  [ 5]
#  [10]
#  [11]
#  [15]
#  [10]
#  [12]
#  [ 4]
#  [ 3]
#  [ 3]
#  [ 2]
#  [ 2]
#  [10]
#  [12]
#  [13]
#  [ 8]
#  [10]
#  [ 2]
#  [ 7]
#  [ 7]
#  [ 3]
#  [11]
#  [ 8]
#  [ 8]
#  [10]
#  [ 9]
#  [ 5]
#  [ 4]
#  [ 4]
#  [ 5]
#  [ 8]
#  [ 4]
#  [ 9]
#  [ 1]
#  [ 8]
#  [ 3]
#  [11]
#  [ 8]
#  [12]
#  [ 3]
#  [ 3]
#  [11]
#  [ 8]
#  [ 6]
#  [10]
#  [ 4]
#  [ 4]
#  [ 3]
#  [ 7]
#  [ 2]
#  [ 9]
#  [ 8]
#  [ 4]
#  [ 5]
#  [ 4]
#  [15]
#  [ 1]
#  [ 5]
#  [ 5]
#  [ 9]
#  [11]
# ...

# %%
#input data
#x_train,x_test,data = info
#y_train,y_test,target = target
x_train,x_test,y_train,y_test = train_test_split(digits_dataset['data'],digits_dataset['target'],test_size=0.4,random_state=0)

# %%
#model
knn = KNeighborsClassifier(n_neighbors=1)

# %%
#training
knn.fit(products_list_x_train,products_list_y_train)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=1, p=2,
#                      weights='uniform')

# %%
#input ข้อมูล
G = float(input("Latitude [18.0]:"))
T = float(input("Longitud [98.0]:"))
# Out:
# Latitude [18.0]:18.555
# Longitud [98.0]:98.555

# %%
#convert input to array
x = np.array([G, T])
print(x)
# Out:
# [18.555 98.555]

# %%
#prediction
# inputA = int(input())
pred = knn.predict([x])

# %%
my_list = ["ศรีภูมิ", "พระสิงห์", "หายยา","ช้างม่อย", "ช้างคลาน", "วัดเกต", "ช้างเผือก", "สุเทพ", "ป่าแดด", "หนองหอย", "ท่าศาลา", "หนองป่าครั่ง", "ฟ้าฮ่าม", "ป่าตัน", "สันผีเสื้อ"]

# %%
if(pred == 1):
  print(my_list[pred[0]-1])
elif(pred == 2):
  print(my_list[pred[0]-1])
elif(pred == 3):
  print(my_list[pred[0]-1])
elif(pred == 4):
  print(my_list[pred[0]-1])
elif(pred == 5):
  print(my_list[pred[0]-1])
elif(pred == 6):
  print(my_list[pred[0]-1])
elif(pred == 7):
  print(my_list[pred[0]-1])
elif(pred == 8):
  print(my_list[pred[0]-1])
elif(pred == 9):
  print(my_list[pred[0]-1])
elif(pred == 10):
  print(my_list[pred[0]-1])
elif(pred == 11):
  print(my_list[pred[0]-1])
elif(pred == 12):
  print(my_list[pred[0]-1])
elif(pred == 13):
  print(my_list[pred[0]-1])
elif(pred == 14):
  print(my_list[pred[0]-1])
else:
  print(my_list[pred[0]-1])
# Out:
# ท่าศาลา

# %%
your_list = ["Red", "Yellow", "Green"]

# %%
if(pred == 4 or pred == 5 or pred == 7):
  x = 0
  print("You are in",your_list[x], "zone")
elif(pred == 10 or pred == 12):
  x = 1
  print("You are in",your_list[x], "zone")
else:
  x = 2
  print("You are in",your_list[x], "zone")
# Out:
# You are in Green zone

# %%
print("Your loacation is",my_list[pred[0]-1],"\nYou are in", your_list[x], "zone")
# Out:
# Your loacation is ท่าศาลา
# You are in Green zone
